# %% [markdown]
# # Introduction to OpenStreetMap (OSM)
# OpenStreetMap (OSM) is a collaborative, open-source mapping platform that provides structured geospatial data from around the world. Unlike traditional maps, OSM data can be downloaded, analyzed, and improved, making it a critical resource for urban mobility projects. This notebook introduces OSM and shows how to access its data using Python and the `OSMnx` library.

# %%
# Install required library
# !pip install osmnx --quiet

# %%
import osmnx as ox
G = ox.graph_from_place('OPorto, Portugal', network_type="drive")
ox.plot_graph(G)

# note: This code can be slow.
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %% [markdown]
# You can also load different types of networks depending on your needs:
#
# ```python
# G = ox.graph_from_place('Oporto, Portugal', network_type='bike')
# ox.plot_graph(G)
# ```
#
# Available types: `'walk'`, `'bike'`, `'drive'`, `'drive_service'`, `'all'`, `'all_private'`.

# %%
# To have a clean visualization, you can remove the nodes using node_size=0.
ox.plot_graph(G, node_size=0)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Summary
# In this episode, you explored how to access and visualize street networks using **OpenStreetMap (OSM)** and the `OSMnx` Python library.
#
# You learned how to download road network data for a specific city (e.g., Oporto), choose the type of network (e.g., `drive`, `walk`, `bike`), and plot it with clean visual styling.
