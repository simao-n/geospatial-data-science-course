# %% [markdown]
# # Module 6 – Episode 23: Clustering for Hotspot Detection (DBSCAN)
#
# In this episode, you'll learn how to detect accident **hotspots** using the DBSCAN clustering algorithm.
# We’ll cluster accident points in Lisbon that are within **50 meters** of each other and visualize the results on an interactive `Folium` map.

# %% [markdown]
# ## Install Required Libraries

# %%
# !pip install folium geopandas scikit-learn --quiet

# %% [markdown]
# ## Load and Convert the Dataset

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium
from sklearn.cluster import DBSCAN
import numpy as np

# Load accident data (dummy data)
df = pd.read_csv("data/Dummy_Accident_Dataset_Lisbon.csv")

# Convert to GeoDataFrame
geometry = [Point(xy) for xy in zip(df["Longitude"], df["Latitude"])]
gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

# Preview
gdf.head()
# Out:
#    ID   Latitude  Longitude  Severity                   geometry
# 0   1  38.731971  -9.127767         1  POINT (-9.12777 38.73197)
# 1   3  38.713751  -9.146390         2  POINT (-9.14639 38.71375)
# 2   4  38.711161  -9.153781         3  POINT (-9.15378 38.71116)
# 3   5  38.736824  -9.121711         1  POINT (-9.12171 38.73682)
# 4   6  38.733835  -9.146536         2  POINT (-9.14654 38.73384)

# %% [markdown]
# ## Apply DBSCAN to Detect Clusters

# %%
# Project to meters (UTM for Lisbon)
gdf_meters = gdf.to_crs(epsg=3763)
coords = np.array(list(zip(gdf_meters.geometry.x, gdf_meters.geometry.y)))

# Run DBSCAN: 50m radius, min 2 points per cluster
db = DBSCAN(eps=50, min_samples=2, metric='euclidean').fit(coords)
gdf["Cluster"] = db.labels_.astype(str)

# Check result
gdf["Cluster"].value_counts()
# Out:
# Cluster
# -1    15
# 2      5
# 1      3
# 0      2
# Name: count, dtype: int64

# %% [markdown]
# ## Plot Clusters on a `Folium` Map

# %%
# Generate base map centered on Lisbon
lisbon_center = [gdf["Latitude"].mean(), gdf["Longitude"].mean()]
map = folium.Map(location=lisbon_center, zoom_start=14, tiles="CartoDB Positron")

# Define color palette
import matplotlib.cm as cm
import matplotlib.colors as colors
unique_clusters = sorted(gdf["Cluster"].unique())
cmap = cm.get_cmap('Set1', len(unique_clusters))
cluster_colors = {cluster: colors.rgb2hex(cmap(i)) for i, cluster in enumerate(unique_clusters)}

# Add points to map
for _, row in gdf.iterrows():
    folium.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=6,
        color=cluster_colors[row["Cluster"]],
        fill=True,
        fill_opacity=0.7,
        popup=f"ID: {row['ID']}<br>Severity: {row['Severity']}<br>Cluster: {row['Cluster']}"
    ).add_to(map)

# Show the map
map
# Out:
# /var/folders/2r/m7459qt92rv4tj2djs64j1700000gn/T/ipykernel_34713/625989988.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set1', len(unique_clusters))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d90e84ce26489e5d5cd3ff451527b288 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d90e84ce26489e5d5cd3ff451527b288&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d90e84ce26489e5d5cd3ff451527b288 = L.map(
#                 &quot;map_d90e84ce26489e5d5cd3ff451527b288&quot;,
#                 {
#                     center: [38.722817680000006, -9.139748959999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53d1868e3bbe899b44c23eff7db92fac = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53d1868e3bbe899b44c23eff7db92fac.addTo(map_d90e84ce26489e5d5cd3ff451527b288);
#
#
#             var circle_marker_5bb1997de4d5448a6a1240eda53adeb7 = L.circleMarker(
#                 [38.731971, -9.127767],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e41a1c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e41a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d90e84ce26489e5d5cd3ff451527b288);
#
#
#         var popup_0afc8ee8c07d92acace7e9ca9a492727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37cfcc3d58b8d4fbb19f4b96e611cca5 = $(`&lt;div id=&quot;html_37cfcc3d58b8d4fbb19f4b96e611cca5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 1&lt;br&gt;Severity: 1&lt;br&gt;Cluster: -1&lt;/div&gt;`)[0];
#                 popup_0afc8ee8c07d92acace7e9ca9a492727.setContent(html_37cfcc3d58b8d4fbb19f4b96e611cca5);
#
#
#
#         circle_marker_5bb1997de4d5448a6a1240eda53adeb7.bindPopup(popup_0afc8ee8c07d92acace7e9ca9a492727)
#         ;
#
#
#
#
#             var circle_marker_0974c05edb1ddd9eb1cb8cc345bc4705 = L.circleMarker(
#                 [38.713751, -9.14639],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e41a1c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e41a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d90e84ce26489e5d5cd3ff451527b288);
#
#
#         var popup_cf88bb1c8d8e05e9ee884db2cb5cca01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce47baf00d55ba7c760dab0844ea2f03 = $(`&lt;div id=&quot;html_ce47baf00d55ba7c760dab0844ea2f03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 3&lt;br&gt;Severity: 2&lt;br&gt;Cluster: -1&lt;/div&gt;`)[0];
#                 popup_cf88bb1c8d8e05e9ee884db2cb5cca01.setContent(html_ce47baf00d55ba7c760dab0844ea2f03);
#
#
#
#         circle_marker_0974c05edb1ddd9eb1cb8cc345bc4705.bindPopup(popup_cf88bb1c8d8e05e9ee884db2cb5cca01)
#         ;
#
#
#
#
#             var circle_marker_41f249ee05f3d9460660df299dc6a5e2 = L.circleMarker(
#                 [38.711161, -9.153781],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e41a1c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e41a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d90e84ce26489e5d5cd3ff451527b288);
#
#
#         var popup_30cd1e7662c52698b09f9b22f7612c7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a881353832843a2a9dcddbcafcb0e01 = $(`&lt;div id=&quot;html_4a881353832843a2a9dcddbcafcb0e01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 4&lt;br&gt;Severity: 3&lt;br&gt;Cluster: -1&lt;/div&gt;`)[0];
#                 popup_30cd1e7662c52698b09f9b22f7612c7d.setContent(html_4a881353832843a2a9dcddbcafcb0e01);
#
#
#
#         circle_marker_41f249ee05f3d9460660df299dc6a5e2.bindPopup(popup_30cd1e7662c52698b09f9b22f7612c7d)
#         ;
#
#
#
#
#             var circle_marker_4430958bde6bb732fe8a1c6eab9fba13

# %% [markdown]
# ## Summary
# In this episode, you learned how to detect spatial **accident hotspots** using the `DBSCAN` clustering algorithm.
#
# You projected geographic coordinates to meters, applied `DBSCAN` to group nearby accident points within 50 meters, and assigned cluster labels to each observation.
# Then, using `Folium`, you visualized the results as an interactive map with color-coded markers representing different clusters.
